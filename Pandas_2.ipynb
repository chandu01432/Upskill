# %% [markdown]
# <a href="https://colab.research.google.com/github/chandu01432/Upskill/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('mtcars2.csv')
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.head()
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
df.tail()
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
df.qsec.mean()
# Out:
# np.float64(17.6748275862069)

# %%
df.qsec = df.qsec.fillna(df.qsec.mean())
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt       qsec  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.674828
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000
# ...

# %%
df = df.drop(columns = ['S.No'])
df
# Out:
#              Unnamed: 1   mpg  cyl   disp   hp  drat     wt       qsec  vs  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.674828   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000   1
# ...

# %%
df = df.rename(columns = {'Unnamed: 1':'Cars'})
df
# Out:
#                    Cars   mpg  cyl   disp   hp  drat     wt       qsec  vs  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.674828   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000   1
# ...

# %%
df[4:20][['mpg','Cars']]
# Out:
#      mpg                 Cars
# 4   18.7    Hornet Sportabout
# 5   18.1              Valiant
# 6   14.3           Duster 360
# 7   24.4            Merc 240D
# 8   22.8             Merc 230
# 9   19.2             Merc 280
# 10  17.8            Merc 280C
# 11  16.4           Merc 450SE
# 12  17.3           Merc 450SL
# 13  15.2          Merc 450SLC
# 14  10.4   Cadillac Fleetwood
# 15  10.4  Lincoln Continental
# 16  14.7    Chrysler Imperial
# 17  32.4             Fiat 128
# 18  30.4          Honda Civic
# 19  33.9       Toyota Corolla

# %%
df.iloc[4:20, 2:5] #stands for integer location
# Out:
#     cyl   disp   hp
# 4     8  360.0  175
# 5     6  225.0  105
# 6     8  360.0  245
# 7     4  146.7   62
# 8     4  140.8   95
# 9     6  167.6  123
# 10    6  167.6  123
# 11    8  275.8  180
# 12    8  275.8  180
# 13    8  275.8  180
# 14    8  472.0  205
# 15    8  460.0  215
# 16    8  440.0  230
# 17    4   78.7   66
# 18    4   75.7   52
# 19    4   71.1   65

# %%
df.loc[4:20, 'Cars':'wt']
# Out:
#                    Cars   mpg  cyl   disp   hp  drat     wt
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# 5               Valiant  18.1    6  225.0  105  2.76  3.460
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615
# ...

# %%
import numpy as np
lst = np.arange(0,32,1)

# %%
df['new column'] = lst

# %%
df.sort_values(by = 'cyl', ascending = False)
# Out:
#                    Cars   mpg  cyl   disp   hp  drat     wt       qsec  vs  \
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.420000   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.600000   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.500000   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.050000   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.410000   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.300000   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.870000   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.400000   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.600000   0
# ...

# %%
df[(df.cyl>4) & (df.am==1)]
# Out:
#               Cars   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
#
#     carb  new column
# 0      4           0
# 1      4           1
# 28     4          28
# 29     6          29
# 30     8          30

# %%
df[df['Cars'].isin(['Mazda RX4', 'Ferrari Dino'])]
# Out:
#             Cars   mpg  cyl   disp   hp  drat    wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110  3.90  2.62  16.46   0   1     4
# 29  Ferrari Dino  19.7    6  145.0  175  3.62  2.77  15.50   0   1     5
#
#     carb  new column
# 0      4           0
# 29     6          29

# %%
df[df['Cars'].str.contains('Mazda')]
# Out:
#             Cars   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0      Mazda RX4  21.0    6  160.0  110   3.9  2.620  16.46   0   1     4
# 1  Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1     4
#
#    carb  new column
# 0     4           0
# 1     4           1

# %%
df['Length Car Names'] = df.Cars.apply(len)

df
# Out:
#                    Cars   mpg  cyl   disp   hp  drat     wt       qsec  vs  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.674828   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000   1
# ...

# %%
def sqr(x):
    return x*x




df['Sqr'] = df.carb.apply(sqr)

df
# Out:
#                    Cars   mpg  cyl   disp   hp  drat     wt       qsec  vs  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.460000   0
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.020000   0
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.610000   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.440000   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.020000   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.674828   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.840000   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.000000   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.900000   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.300000   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.900000   1
# ...
